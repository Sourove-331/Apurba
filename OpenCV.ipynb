# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourove-331/Apurba/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
path_location = "/content/drive/MyDrive/Apurba/Mini_Dataset/Mini_Dataset/East_Asian/1284.jpg"

# %%
image = cv2.imread (path_location,1)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)

cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F70B9D1BAD0>

# %%
resized_image = cv2.resize(image, (200,200))

cv2_imshow(resized_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F70B9D0F690>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2_imshow(gray_image)

cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7F70B7CAFB10>
